# %% [markdown]
# ## 목표
#
# - Kobert-Transformers 대신 KoELECTRA를 사용해 CNN 모델과 각각 특징을 추출하여 소프트보팅 앙상블 모델을 만든다
# - KFold를 이용해 다양한 학습을 하게 하여 성능을 높인다

# %% [markdown]
# ### 순서
# - 1. 필요 모듈들 설치 및 임포트
# - 2. 기본 데이터 불러오기
# - 3. 필요한 함수들 설정(모델 포함)
# - 4. 모델 매개변수 설정
# - 5. 모델학습
# - 6. 평가
# - 7. 예측

# %% [markdown]
# #### 1. 필요 모듈들 설치 및 임포트

# %%
# !pip install scikeras --users
# Out:
# Collecting scikeras
#   Using cached scikeras-0.13.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: keras>=3.2.0 in c:\users\smhrd\anaconda3\lib\site-packages (from scikeras) (3.3.3)
# Collecting scikit-learn>=1.4.2 (from scikeras)
#   Using cached scikit_learn-1.4.2-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: absl-py in c:\users\smhrd\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras) (2.1.0)
# Requirement already satisfied: numpy in c:\users\smhrd\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras) (1.26.4)
# Requirement already satisfied: rich in c:\users\smhrd\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras) (13.3.5)
# Requirement already satisfied: namex in c:\users\smhrd\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras) (0.0.7)
# Requirement already satisfied: h5py in c:\users\smhrd\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras) (3.11.0)
# Requirement already satisfied: optree in c:\users\smhrd\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras) (0.11.0)
# Requirement already satisfied: ml-dtypes in c:\users\smhrd\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras) (0.3.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\smhrd\anaconda3\lib\site-packages (from scikit-learn>=1.4.2->scikeras) (1.13.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\smhrd\anaconda3\lib\site-packages (from scikit-learn>=1.4.2->scikeras) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\smhrd\anaconda3\lib\site-packages (from scikit-learn>=1.4.2->scikeras) (2.2.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\smhrd\anaconda3\lib\site-packages (from optree->keras>=3.2.0->scikeras) (4.11.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\smhrd\anaconda3\lib\site-packages (from rich->keras>=3.2.0->scikeras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\smhrd\anaconda3\lib\site-packages (from rich->keras>=3.2.0->scikeras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\smhrd\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.0)
# Using cached scikeras-0.13.0-py3-none-any.whl (26 kB)
# Using cached scikit_learn-1.4.2-cp311-cp311-win_amd64.whl (10.6 MB)
# Installing collected packages: scikit-learn, scikeras
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Rolling back uninstall of scikit-learn
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\scikit_learn-1.2.2.dist-info\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\~cikit_learn-1.2.2.dist-info
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\.libs\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\~libs
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\__check_build\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\~_check_build
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\__init__.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\__init__.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\__pycache__\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\~_pycache__
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\_build_utils\__init__.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\_build_utils\__init__.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\_build_utils\__pycache__\__init__.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\_build_utils\__pycache__\__init__.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\_build_utils\__pycache__\openmp_helpers.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\_build_utils\__pycache__\openmp_helpers.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\_build_utils\__pycache__\pre_build_helpers.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\_build_utils\__pycache__\pre_build_helpers.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\_build_utils\openmp_helpers.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\_build_utils\openmp_helpers.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\_build_utils\pre_build_helpers.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\_build_utils\pre_build_helpers.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\_config.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\_config.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\_distributor_init.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\_distributor_init.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\_isotonic.cp311-win_amd64.pyd
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\_isotonic.cp311-win_amd64.pyd
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\_loss\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\~loss
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\_min_dependencies.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\_min_dependencies.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\base.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\base.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\calibration.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\calibration.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\__init__.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\__init__.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\__pycache__\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\cluster\~_pycache__
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\_affinity_propagation.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\_affinity_propagation.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\_agglomerative.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\_agglomerative.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\_bicluster.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\_bicluster.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\_birch.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\_birch.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\_bisect_k_means.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\_bisect_k_means.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\_dbscan.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\_dbscan.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\_dbscan_inner.cp311-win_amd64.pyd
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\_dbscan_inner.cp311-win_amd64.pyd
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\_feature_agglomeration.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\_feature_agglomeration.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\_hierarchical_fast.cp311-win_amd64.pyd
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\_hierarchical_fast.cp311-win_amd64.pyd
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\_k_means_common.cp311-win_amd64.pyd
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\_k_means_common.cp311-win_amd64.pyd
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\_k_means_common.pxd
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\_k_means_common.pxd
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\_k_means_elkan.cp311-win_amd64.pyd
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\_k_means_elkan.cp311-win_amd64.pyd
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\_k_means_lloyd.cp311-win_amd64.pyd
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\_k_means_lloyd.cp311-win_amd64.pyd
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\_k_means_minibatch.cp311-win_amd64.pyd
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\_k_means_minibatch.cp311-win_amd64.pyd
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\_kmeans.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\_mean_shift.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\_mean_shift.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\_optics.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\_optics.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\_spectral.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\_spectral.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\tests\__init__.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\tests\__init__.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\tests\__pycache__\__init__.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\tests\__pycache__\__init__.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\tests\__pycache__\common.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\tests\__pycache__\common.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\tests\__pycache__\test_affinity_propagation.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\tests\__pycache__\test_affinity_propagation.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\tests\__pycache__\test_bicluster.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\tests\__pycache__\test_bicluster.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\tests\__pycache__\test_birch.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\tests\__pycache__\test_birch.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\tests\__pycache__\test_bisect_k_means.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\tests\__pycache__\test_bisect_k_means.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\tests\__pycache__\test_dbscan.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\tests\__pycache__\test_dbscan.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\tests\__pycache__\test_feature_agglomeration.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\tests\__pycache__\test_feature_agglomeration.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\tests\__pycache__\test_hierarchical.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\tests\__pycache__\test_hierarchical.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\tests\__pycache__\test_k_means.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\tests\__pycache__\test_k_means.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\tests\__pycache__\test_mean_shift.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\tests\__pycache__\test_mean_shift.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\tests\__pycache__\test_optics.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\tests\__pycache__\test_optics.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\tests\__pycache__\test_spectral.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\tests\__pycache__\test_spectral.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\tests\common.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\tests\common.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\tests\test_affinity_propagation.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\tests\test_affinity_propagation.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\tests\test_bicluster.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\tests\test_bicluster.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\tests\test_birch.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\tests\test_birch.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\tests\test_bisect_k_means.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\tests\test_bisect_k_means.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\tests\test_dbscan.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\tests\test_dbscan.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\tests\test_feature_agglomeration.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\tests\test_feature_agglomeration.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\tests\test_hierarchical.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\tests\test_hierarchical.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\tests\test_k_means.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\tests\test_k_means.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\tests\test_mean_shift.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\tests\test_mean_shift.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\tests\test_optics.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\tests\test_optics.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cluster\tests\test_spectral.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\cluster\tests\test_spectral.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\compose\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\~ompose
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\conftest.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\conftest.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\covariance\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\~ovariance
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\cross_decomposition\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\~ross_decomposition
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\__init__.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\datasets\__init__.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\__pycache__\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\datasets\~_pycache__
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\_arff_parser.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\datasets\_arff_parser.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\_base.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\datasets\_base.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\_california_housing.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\datasets\_california_housing.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\_covtype.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\datasets\_covtype.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\_kddcup99.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\datasets\_kddcup99.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\_lfw.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\datasets\_lfw.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\_olivetti_faces.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\datasets\_olivetti_faces.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\_openml.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\datasets\_openml.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\_rcv1.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\datasets\_rcv1.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\_samples_generator.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\datasets\_samples_generator.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\_species_distributions.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\datasets\_species_distributions.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\_svmlight_format_fast.cp311-win_amd64.pyd
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\datasets\_svmlight_format_fast.cp311-win_amd64.pyd
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\_svmlight_format_io.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\datasets\_svmlight_format_io.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\_twenty_newsgroups.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\datasets\_twenty_newsgroups.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\data\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\datasets\~ata
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\descr\__init__.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\datasets\descr\__init__.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\descr\__pycache__\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\datasets\descr\~_pycache__
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\descr\breast_cancer.rst
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\datasets\descr\breast_cancer.rst
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\descr\california_housing.rst
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\datasets\descr\california_housing.rst
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\descr\covtype.rst
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\datasets\descr\covtype.rst
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\descr\diabetes.rst
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\datasets\descr\diabetes.rst
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\descr\digits.rst
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\datasets\descr\digits.rst
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\descr\iris.rst
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\datasets\descr\iris.rst
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\descr\kddcup99.rst
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\datasets\descr\kddcup99.rst
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\descr\lfw.rst
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\datasets\descr\lfw.rst
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\descr\linnerud.rst
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\datasets\descr\linnerud.rst
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\descr\olivetti_faces.rst
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\datasets\descr\olivetti_faces.rst
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\descr\rcv1.rst
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\datasets\descr\rcv1.rst
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\descr\twenty_newsgroups.rst
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\datasets\descr\twenty_newsgroups.rst
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\descr\wine_data.rst
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\datasets\descr\wine_data.rst
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\images\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\datasets\~mages
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\datasets\tests\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\datasets\~ests
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\decomposition\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\~ecomposition
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\discriminant_analysis.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\discriminant_analysis.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\dummy.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\dummy.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\ensemble\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\~nsemble
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\exceptions.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\exceptions.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\experimental\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\~xperimental
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\externals\__init__.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\externals\__init__.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\externals\__pycache__\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\externals\~_pycache__
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\externals\_arff.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\externals\_arff.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\externals\_lobpcg.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\externals\_lobpcg.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\externals\_packaging\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\externals\~packaging
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\externals\conftest.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\externals\conftest.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\feature_extraction\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\~eature_extraction
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\feature_selection\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\~eature_selection
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\gaussian_process\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\~aussian_process
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\impute\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\~mpute
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\inspection\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\~nspection
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\isotonic.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\isotonic.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\kernel_approximation.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\kernel_approximation.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\kernel_ridge.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\kernel_ridge.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\linear_model\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\~inear_model
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\manifold\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\~anifold
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\metrics\__init__.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\metrics\__init__.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\metrics\__pycache__\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\metrics\~_pycache__
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\metrics\_base.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\metrics\_base.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\metrics\_classification.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\metrics\_classification.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\metrics\_dist_metrics.cp311-win_amd64.pyd
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\metrics\_dist_metrics.cp311-win_amd64.pyd
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\metrics\_dist_metrics.pxd
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\metrics\_dist_metrics.pxd
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\__init__.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\metrics\_pairwise_distances_reduction\__init__.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\__pycache__\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\~_pycache__
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_argkmin.cp311-win_amd64.pyd
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\metrics\_pairwise_distances_reduction\_argkmin.cp311-win_amd64.pyd
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_argkmin.pxd
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\metrics\_pairwise_distances_reduction\_argkmin.pxd
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_base.cp311-win_amd64.pyd
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\metrics\_pairwise_distances_reduction\_base.cp311-win_amd64.pyd
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_base.pxd
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\metrics\_pairwise_distances_reduction\_base.pxd
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_datasets_pair.cp311-win_amd64.pyd
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\metrics\_pairwise_distances_reduction\_datasets_pair.cp311-win_amd64.pyd
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_datasets_pair.pxd
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\metrics\_pairwise_distances_reduction\_datasets_pair.pxd
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_dispatcher.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\metrics\_pairwise_distances_reduction\_dispatcher.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_middle_term_computer.cp311-win_amd64.pyd
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\metrics\_pairwise_distances_reduction\_middle_term_computer.cp311-win_amd64.pyd
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_middle_term_computer.pxd
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\metrics\_pairwise_distances_reduction\_middle_term_computer.pxd
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_radius_neighbors.cp311-win_amd64.pyd
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\metrics\_pairwise_distances_reduction\_radius_neighbors.cp311-win_amd64.pyd
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_radius_neighbors.pxd
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\metrics\_pairwise_distances_reduction\_radius_neighbors.pxd
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\metrics\_pairwise_fast.cp311-win_amd64.pyd
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\metrics\_pairwise_fast.cp311-win_amd64.pyd
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\metrics\_plot\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\metrics\~plot
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\metrics\_ranking.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\metrics\_ranking.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\metrics\_regression.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\metrics\_regression.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\metrics\_scorer.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\metrics\cluster\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\metrics\~luster
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\metrics\pairwise.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\metrics\tests\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\metrics\~ests
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\mixture\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\~ixture
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\model_selection\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\~odel_selection
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\multiclass.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\multiclass.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\multioutput.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\multioutput.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\naive_bayes.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\naive_bayes.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\neighbors\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\~eighbors
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\neural_network\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\~eural_network
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\pipeline.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\pipeline.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\preprocessing\__init__.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\preprocessing\__init__.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\preprocessing\__pycache__\__init__.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\preprocessing\__pycache__\__init__.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\preprocessing\__pycache__\_data.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\preprocessing\__pycache__\_data.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\preprocessing\__pycache__\_discretization.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\preprocessing\__pycache__\_discretization.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\preprocessing\__pycache__\_encoders.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\preprocessing\__pycache__\_encoders.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\preprocessing\__pycache__\_function_transformer.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\preprocessing\__pycache__\_function_transformer.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\preprocessing\__pycache__\_label.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\preprocessing\__pycache__\_label.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\preprocessing\__pycache__\_polynomial.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\preprocessing\__pycache__\_polynomial.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\preprocessing\_csr_polynomial_expansion.cp311-win_amd64.pyd
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\preprocessing\_csr_polynomial_expansion.cp311-win_amd64.pyd
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\preprocessing\_data.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\preprocessing\_discretization.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\preprocessing\_discretization.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\preprocessing\_encoders.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\preprocessing\_function_transformer.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\preprocessing\_function_transformer.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\preprocessing\_label.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\preprocessing\_polynomial.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\preprocessing\_polynomial.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\preprocessing\tests\__init__.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\preprocessing\tests\__init__.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\preprocessing\tests\__pycache__\__init__.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\preprocessing\tests\__pycache__\__init__.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\preprocessing\tests\__pycache__\test_common.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\preprocessing\tests\__pycache__\test_common.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\preprocessing\tests\__pycache__\test_data.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\preprocessing\tests\__pycache__\test_data.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\preprocessing\tests\__pycache__\test_discretization.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\preprocessing\tests\__pycache__\test_discretization.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\preprocessing\tests\__pycache__\test_encoders.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\preprocessing\tests\__pycache__\test_encoders.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\preprocessing\tests\__pycache__\test_function_transformer.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\preprocessing\tests\__pycache__\test_function_transformer.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\preprocessing\tests\__pycache__\test_label.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\preprocessing\tests\__pycache__\test_label.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\preprocessing\tests\__pycache__\test_polynomial.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\preprocessing\tests\__pycache__\test_polynomial.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\preprocessing\tests\test_common.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\preprocessing\tests\test_common.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\preprocessing\tests\test_data.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\preprocessing\tests\test_data.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\preprocessing\tests\test_discretization.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\preprocessing\tests\test_discretization.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\preprocessing\tests\test_encoders.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\preprocessing\tests\test_encoders.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\preprocessing\tests\test_function_transformer.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\preprocessing\tests\test_function_transformer.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\preprocessing\tests\test_label.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\preprocessing\tests\test_label.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\preprocessing\tests\test_polynomial.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\preprocessing\tests\test_polynomial.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\random_projection.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\random_projection.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\semi_supervised\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\~emi_supervised
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\svm\
#    from C:\Users\smhrd\anaconda3\Lib\site-packages\sklearn\~vm
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\__init__.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\__init__.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\__pycache__\__init__.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\__pycache__\__init__.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\__pycache__\random_seed.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\__pycache__\random_seed.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\__pycache__\test_base.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\__pycache__\test_base.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\__pycache__\test_build.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\__pycache__\test_build.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\__pycache__\test_calibration.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\__pycache__\test_calibration.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\__pycache__\test_check_build.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\__pycache__\test_check_build.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\__pycache__\test_common.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\__pycache__\test_common.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\__pycache__\test_config.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\__pycache__\test_config.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\__pycache__\test_discriminant_analysis.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\__pycache__\test_discriminant_analysis.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\__pycache__\test_docstring_parameters.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\__pycache__\test_docstring_parameters.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\__pycache__\test_docstrings.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\__pycache__\test_docstrings.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\__pycache__\test_dummy.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\__pycache__\test_dummy.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\__pycache__\test_init.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\__pycache__\test_init.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\__pycache__\test_isotonic.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\__pycache__\test_isotonic.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\__pycache__\test_kernel_approximation.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\__pycache__\test_kernel_approximation.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\__pycache__\test_kernel_ridge.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\__pycache__\test_kernel_ridge.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\__pycache__\test_metaestimators.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\__pycache__\test_metaestimators.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\__pycache__\test_min_dependencies_readme.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\__pycache__\test_min_dependencies_readme.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\__pycache__\test_multiclass.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\__pycache__\test_multiclass.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\__pycache__\test_multioutput.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\__pycache__\test_multioutput.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\__pycache__\test_naive_bayes.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\__pycache__\test_naive_bayes.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\__pycache__\test_pipeline.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\__pycache__\test_pipeline.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\__pycache__\test_public_functions.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\__pycache__\test_public_functions.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\__pycache__\test_random_projection.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\__pycache__\test_random_projection.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\random_seed.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\random_seed.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\test_base.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\test_base.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\test_build.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\test_build.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\test_calibration.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\test_calibration.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\test_check_build.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\test_check_build.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\test_common.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\test_common.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\test_config.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\test_config.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\test_discriminant_analysis.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\test_discriminant_analysis.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\test_docstring_parameters.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\test_docstring_parameters.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\test_docstrings.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\test_docstrings.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\test_dummy.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\test_dummy.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\test_init.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\test_init.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\test_isotonic.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\test_isotonic.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\test_kernel_approximation.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\test_kernel_approximation.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\test_kernel_ridge.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\tests\test_kernel_ridge.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\tests\test_metaestimators.py
# ...
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\stats.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__init__.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__init__.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\__init__.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\__init__.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_arpack.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_arpack.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_array_api.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_array_api.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_arrayfuncs.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_arrayfuncs.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_class_weight.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_class_weight.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_cython_blas.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_cython_blas.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_cython_templating.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_cython_templating.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_deprecation.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_deprecation.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_encode.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_encode.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_estimator_checks.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_estimator_checks.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_estimator_html_repr.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_estimator_html_repr.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_extmath.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_extmath.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_fast_dict.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_fast_dict.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_fixes.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_fixes.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_graph.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_graph.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_metaestimators.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_metaestimators.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_mocking.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_mocking.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_multiclass.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_multiclass.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_murmurhash.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_murmurhash.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_optimize.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_optimize.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_parallel.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_parallel.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_param_validation.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_param_validation.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_pprint.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_pprint.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_random.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_random.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_readonly_wrapper.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_readonly_wrapper.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_seq_dataset.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_seq_dataset.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_set_output.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_set_output.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_shortest_path.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_shortest_path.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_show_versions.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_show_versions.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_sparsefuncs.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_sparsefuncs.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_stats.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_stats.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_tags.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_tags.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_testing.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_testing.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_utils.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_utils.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_validation.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_validation.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\__pycache__\test_weight_vector.cpython-311.pyc
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\__pycache__\test_weight_vector.cpython-311.pyc
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_arpack.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_arpack.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_array_api.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_array_api.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_arrayfuncs.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_arrayfuncs.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_class_weight.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_class_weight.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_cython_blas.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_cython_blas.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_cython_templating.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_cython_templating.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_deprecation.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_deprecation.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_encode.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_encode.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_estimator_checks.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_estimator_checks.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_estimator_html_repr.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_estimator_html_repr.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_extmath.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_extmath.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_fast_dict.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_fast_dict.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_fixes.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_fixes.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_graph.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_graph.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_metaestimators.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_metaestimators.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_mocking.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_mocking.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_multiclass.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_multiclass.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_murmurhash.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_murmurhash.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_optimize.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_optimize.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_parallel.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_parallel.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_param_validation.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_param_validation.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_pprint.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_pprint.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_random.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_random.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_readonly_wrapper.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_readonly_wrapper.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_seq_dataset.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_seq_dataset.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_set_output.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_set_output.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_shortest_path.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_shortest_path.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_show_versions.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_show_versions.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_sparsefuncs.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_sparsefuncs.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_stats.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_stats.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_tags.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_tags.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_testing.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_testing.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_utils.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_utils.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_validation.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_validation.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\tests\test_weight_vector.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\tests\test_weight_vector.py
#   Moving to c:\users\smhrd\anaconda3\lib\site-packages\sklearn\utils\validation.py
#    from C:\Users\smhrd\AppData\Local\Temp\pip-uninstall-0nph_v6c\utils\validation.py
# ERROR: Could not install packages due to an OSError: [WinError 5] 액세스가 거부되었습니다: 'C:\\Users\\smhrd\\anaconda3\\Lib\\site-packages\\sklearn\\cluster\\_hdbscan\\_linkage.cp311-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
import librosa
# import librosa.display
# import IPython.display as ipd
# from IPython.display import Audio

# from random import randint
import numpy as np
import pandas as pd
# import pydub #오디오 파일을 다루는 라이브러리 : 변환 조작 재생 분석 등
# import gTTS # 텍스트를 음성으로 변환하는 라이브러리. 나는 당장 쓸 일 없을 듯?

from tqdm import tqdm, tqdm_notebook
# import np_utils
# import matplotlib.pyplot as plt
# import seaborn as sns

# import nlpaug.augmenter.audio as naa
# import wave

import glob
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
os.environ['TORCH_USE_CUDA_DSA'] = '1'

import winsound as ws
import json
# import shutil
# import sys
# import logging
# import unicodedata
# from shutil import copyfile
# import warnings
# warnings.filterwarnings("always")


from sklearn.preprocessing import LabelEncoder,StandardScaler, MinMaxScaler, RobustScaler, FunctionTransformer
# from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import recall_score,precision_score
from sklearn.model_selection import train_test_split, KFold
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from scikeras.wrappers import KerasClassifier 

from sklearn.metrics import accuracy_score, f1_score
# from sklearn.svm import SVC 
# from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline

import joblib
from joblib import dump, load
# from xgboost import XGBClassifier 

# import keras
import tensorflow as tf
from keras.callbacks import ReduceLROnPlateau,ModelCheckpoint,EarlyStopping, Callback
from keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense, Conv1D, MaxPooling1D, Flatten, Dropout, concatenate
# from tensorflow.keras.optimizers import Adam
# from keras.preprocessing.sequence import pad_sequences
# from keras.utils import to_categorical
# from sentence_transformers import SentenceTransformer
from keras.metrics import Precision, Recall, F1Score

import torch
from torch import nn
import torch.optim as optim
from torch.optim import AdamW
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

# np.bool = np.bool_

# import mxnet
# import gluonnlp as nlp

# from transformers import AdamW
# from transformers.optimization import get_cosine_schedule_with_warmup
# from transformers import BertModel

from audiomentations import Compose, AddGaussianNoise, TimeStretch, PitchShift, Shift # 음성 데이터 증강용

# %% [markdown]
# #### 2. 기본 데이터 불러오기

# %%
train_csv = pd.read_csv('e:/Data2/csv/train.csv')
test_csv = pd.read_csv('e:/Data2/csv/test.csv')
exam_list = ['5fbe364744697678c497c07f','5fbe361844697678c497c07e']

train_audio_path = 'e:/Data2/train/'
test_audio_path = 'e:/Data2/test/'
exam_audio_path = 'e:/Data2/exam/'

# X = np.load('./features/train_features_6.npy')
X = np.load('./features/train_features_8.npy')  #6번 특징이 별로 안 좋을 경우 시도
X = np.real(X) #복소수 형태로 값이 나왔음
y = train_csv.iloc[:,-7:]
y= np.array(y)

# X_val = np.load('./features/test_features_6.npy')
X_test = np.load('./features/test_features_8.npy')
X_test = np.real(X_test)
y_test = test_csv.iloc[:,-7:]
y_test = np.array(y_val)

# %% [markdown]
# #### 3. 필요한 함수들 설정(모델 포함)
# - 비프음 함수
# - 음성 특징 학습 함수(CNN)
# - 문자 특징 학습 모델(KoELECTRA)

# %%
#에러 발생 혹은 작업 완료시 beep로 알리기
def beepError():
    fr = 1000    # range : 37 ~ 32767
    du = 2000     # 1000 ms ==1second
    ws.Beep(fr, du) # winsound.Beep(frequency, duration)

def beepSuccess():
    fr = 2000    # range : 37 ~ 32767
    du = 1000     # 1000 ms ==1second
    ws.Beep(fr, du) # winsound.Beep(frequency, duration)

# %%
# f1 스코어를 쓸 수 있게 만드는 함수
# f1 스코어의 결과 타입은 tensor이므로 이걸 변환해 주는 작업 필요.

# class F1ScoreCallback(Callback):
#     def __init__(self, validation_data, save_best_only=True):
#         super(F1ScoreCallback, self).__init__()
#         self.X_val, self.y_val = validation_data
#         self.save_best_only = save_best_only
#         self.best_f1 = 0

#     def on_epoch_end(self, epoch, logs=None):
#         y_pred = np.argmax(self.model.predict(self.X_val), axis=1)
#         f1_val = f1_score(np.argmax(self.y_val, axis=1), y_pred, average='weighted')
#         print(f' - val_f1_score: {f1_val:.4f}')
#         if f1_val > self.best_f1:
#             self.best_f1 = f1_val
#             self.model.save('./model/best_model.keras')
#             print("Best F1 score. Model saved.")
#         elif not self.save_best_only:
#             self.model.save('./model/best_model.keras')
#             print("Model saved.")
#         if logs is not None:
#             logs['val_f1_score'] = f1_val

# %%
# 음성 모델
def cnn_model(data):
    model=Sequential()
    model.add(InputLayer(shape=(data.shape[1],data.shape[2])))
    model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu'))
    model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

    model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu'))
    model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

    model.add(Conv1D(128, kernel_size=5, strides=1, padding='same', activation='relu'))
    model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))
    model.add(Dropout(0.2))

    model.add(Conv1D(64, kernel_size=5, strides=1, padding='same', activation='relu'))
    model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

    model.add(Flatten())
    model.add(Dense(units=32, activation='relu'))
    model.add(Dropout(0.3))

    model.add(Dense(units=7, activation='softmax'))
    model.compile(optimizer = 'adamW' , loss = 'categorical_crossentropy' , metrics = ['accuracy','f1_score']) #metrics 추가

    return model

# %%
class ElectraForMultiClassClassification(nn.Module):
    def __init__(self, num_classes):
        super(ElectraForMultiClassClassification, self).__init__()
        self.electra = ElectraModel.from_pretrained("monologg/koelectra-base-v3-discriminator")
        self.dropout = nn.Dropout(0.1)
        self.classifier = nn.Linear(self.electra.config.hidden_size, num_classes)

    def forward(self, input_ids, attention_mask):
        outputs = self.electra(input_ids=input_ids, attention_mask=attention_mask)
        pooled_output = outputs.last_hidden_state[:, 0]  # [CLS] 토큰의 표현
        pooled_output = self.dropout(pooled_output)
        logits = self.classifier(pooled_output)
        return logits

# %%
class Text_Input(Dataset):

    def __init__(self, data):
        self.data = data
        self.data.loc[(train_csv['감정'] == "Fear"), '감정'] = 0
        self.data.loc[(train_csv['감정'] == "Surprise"), '감정'] = 1
        self.data.loc[(train_csv['감정'] == "Angry"), '감정'] = 2
        self.data.loc[(train_csv['감정'] == "Sadness"), '감정'] = 3
        self.data.loc[(train_csv['감정'] == "Neutral"), '감정'] = 4
        self.data.loc[(train_csv['감정'] == "Happiness"), '감정'] = 5
        self.data.loc[(train_csv['감정'] == "Disgust"), '감정'] = 6
        self.tokenizer =  ElectraTokenizer.from_pretrained("monologg/koelectra-base-v3-discriminator")


    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        row = self.data.iloc[idx, 1:3].values
        text = row[0]
        y = row[1]

        inputs = self.tokenizer(
            text,
            return_tensors='pt',
            truncation=True,
            max_length=256,
            padding='max_length',
            add_special_tokens=True
            )

        input_ids = inputs['input_ids'][0]
        attention_mask = inputs['attention_mask'][0]

        return input_ids, attention_mask, y

# %%
# 기본적인 사전 설정
rlrp = ReduceLROnPlateau(monitor='loss', factor=0.4, verbose=0, patience=5, min_lr=0.0000001) #learning rate 조절 
modelpath = './model/model_{epoch:02d}-{val_accuracy:.4f}.keras'
# modelpath = './model/model_{epoch:02d}-{f1_score:.4f}.keras'


mcp = ModelCheckpoint(
    modelpath,     #저장할 모델의 경로
  monitor = 'val_accuracy', #val_f1_score를 기준으로 전보다 모델이 나아지는 걸 확인
 
  save_best_only = True,    #나아진 결과만 저장
#     save_weights_only=True , #이걸 써 줘야 weights.h5로 저장 가능하다.
  verbose = 1               #과정을 출력
)

#전보다 나아지지 않으면 학습중단

es = EarlyStopping(
    monitor = 'val_accuracy',
#     mode='max',
    patience = 5,    # 전보다 나아지지 않아도 실행할 횟수
    restore_best_weights=True
)

# %%
kf = KFold(n_splits=5, shuffle=True)
best_score = 0
best_model = None

# KFold를 통한 데이터 분할 및 스케일링
for train_index, test_index in kf.split(X):
    X_train, X_valid = X[train_index], X[test_index]
    y_train, y_valid = y[train_index], y[test_index]
    
    # 스케일링을 위한 StandardScaler 객체 생성 및 학습 데이터에 fit
#     scaler = StandardScaler()
#     scaler = MinMaxScaler()
    scaler = RobustScaler()
    scaler = scaler.fit(X_train)
    X_train_scaled = scaler.transform(X_train)
    
    # 학습 데이터와 동일한 스케일링을 테스트 데이터에 적용
    X_valid_scaled = scaler.transform(X_valid)
    
    X_train_scaled  = np.expand_dims(X_train_scaled,axis =1)
    X_valid_scaled = np.expand_dims(X_valid_scaled ,axis =1)
    
    # 모델 학습
    model = cnn_model(X_train_scaled)
    history=model.fit(
    X_train_scaled,
    y_train,batch_size=32, #32일 때 약 35% 성능, 16일 때 약 35.2% 성능, 8일 때는 약 41.4%
    epochs=50, 
    validation_data=(X_valid_scaled , y_valid), 
    callbacks=[rlrp,mcp,es]
    )
    
    # 모델 평가
    val_loss, val_acc, val_f1_score = model.evaluate(X_valid_scaled, y_valid)
    
    X_test_scaled = scaler.transform(X_test)
    X_test_scaled = np.expand_dims(X_test_scaled  ,axis =1)
    
    test_loss, test_acc, test_f1_score = model.evaluate(X_test_scaled, y_test)
    
    print("Valid Loss: ",val_loss, end=', ')
    print("Valid f1_score: ",val_f1_score, end=', ')
    print("Valid Accuracy: ",val_acc, end=', ')
    print("Test Loss: ",test_loss, end=', ')
    print("Test f1_score: ",test_f1_score, end=', ')
    print("Test Accuracy: ",test_acc, end=', ')
    
    
    if test_acc>best_score:
        best_score = test_acc
        best_model = model
        print('더 나은 test_acc 모델 저장!')
        
beepSuccess()
# Out:
# Epoch 1/50
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3732 - f1_score: 0.1212 - loss: 1.6757
# Epoch 1: val_accuracy improved from -inf to 0.43256, saving model to ./model/model_01-0.4326.keras
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - accuracy: 0.3732 - f1_score: 0.1213 - loss: 1.6757 - val_accuracy: 0.4326 - val_f1_score: 0.2029 - val_loss: 1.5448 - learning_rate: 0.0010
# Epoch 2/50
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4200 - f1_score: 0.1948 - loss: 1.5601
# Epoch 2: val_accuracy improved from 0.43256 to 0.44254, saving model to ./model/model_02-0.4425.keras
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.4200 - f1_score: 0.1948 - loss: 1.5601 - val_accuracy: 0.4425 - val_f1_score: 0.2139 - val_loss: 1.5122 - learning_rate: 0.0010
# Epoch 3/50
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4448 - f1_score: 0.2154 - loss: 1.5113
# Epoch 3: val_accuracy improved from 0.44254 to 0.44923, saving model to ./model/model_03-0.4492.keras
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 14s 15ms/step - accuracy: 0.4448 - f1_score: 0.2154 - loss: 1.5113 - val_accuracy: 0.4492 - val_f1_score: 0.2354 - val_loss: 1.4906 - learning_rate: 0.0010
# Epoch 4/50
# 987/990 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4625 - f1_score: 0.2391 - loss: 1.4840
# Epoch 4: val_accuracy improved from 0.44923 to 0.44973, saving model to ./model/model_04-0.4497.keras
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.4625 - f1_score: 0.2390 - loss: 1.4840 - val_accuracy: 0.4497 - val_f1_score: 0.2368 - val_loss: 1.5057 - learning_rate: 0.0010
# Epoch 5/50
# 987/990 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4622 - f1_score: 0.2471 - loss: 1.4638
# Epoch 5: val_accuracy improved from 0.44973 to 0.46034, saving model to ./model/model_05-0.4603.keras
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.4623 - f1_score: 0.2471 - loss: 1.4638 - val_accuracy: 0.4603 - val_f1_score: 0.2421 - val_loss: 1.4825 - learning_rate: 0.0010
# Epoch 6/50
# 989/990 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4807 - f1_score: 0.2661 - loss: 1.4328
# Epoch 6: val_accuracy did not improve from 0.46034
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.4807 - f1_score: 0.2661 - loss: 1.4328 - val_accuracy: 0.4562 - val_f1_score: 0.2472 - val_loss: 1.4582 - learning_rate: 0.0010
# Epoch 7/50
# 988/990 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4879 - f1_score: 0.2768 - loss: 1.4067
# Epoch 7: val_accuracy improved from 0.46034 to 0.46805, saving model to ./model/model_07-0.4680.keras
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.4879 - f1_score: 0.2768 - loss: 1.4067 - val_accuracy: 0.4680 - val_f1_score: 0.2625 - val_loss: 1.4511 - learning_rate: 0.0010
# Epoch 8/50
# 987/990 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4991 - f1_score: 0.2945 - loss: 1.3863
# Epoch 8: val_accuracy improved from 0.46805 to 0.46893, saving model to ./model/model_08-0.4689.keras
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.4991 - f1_score: 0.2945 - loss: 1.3863 - val_accuracy: 0.4689 - val_f1_score: 0.2701 - val_loss: 1.4432 - learning_rate: 0.0010
# Epoch 9/50
# 988/990 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5034 - f1_score: 0.3030 - loss: 1.3675
# Epoch 9: val_accuracy did not improve from 0.46893
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.5034 - f1_score: 0.3030 - loss: 1.3675 - val_accuracy: 0.4614 - val_f1_score: 0.2655 - val_loss: 1.4816 - learning_rate: 0.0010
# Epoch 10/50
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5197 - f1_score: 0.3267 - loss: 1.3451
# Epoch 10: val_accuracy did not improve from 0.46893
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.5197 - f1_score: 0.3267 - loss: 1.3451 - val_accuracy: 0.4674 - val_f1_score: 0.2716 - val_loss: 1.4508 - learning_rate: 0.0010
# Epoch 11/50
# 987/990 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5257 - f1_score: 0.3364 - loss: 1.3169
# Epoch 11: val_accuracy improved from 0.46893 to 0.47335, saving model to ./model/model_11-0.4734.keras
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.5257 - f1_score: 0.3364 - loss: 1.3169 - val_accuracy: 0.4734 - val_f1_score: 0.2804 - val_loss: 1.4615 - learning_rate: 0.0010
# Epoch 12/50
# 989/990 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5319 - f1_score: 0.3483 - loss: 1.2970
# Epoch 12: val_accuracy did not improve from 0.47335
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.5319 - f1_score: 0.3482 - loss: 1.2970 - val_accuracy: 0.4680 - val_f1_score: 0.2841 - val_loss: 1.4776 - learning_rate: 0.0010
# Epoch 13/50
# 987/990 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5413 - f1_score: 0.3639 - loss: 1.2777
# Epoch 13: val_accuracy did not improve from 0.47335
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.5413 - f1_score: 0.3639 - loss: 1.2777 - val_accuracy: 0.4663 - val_f1_score: 0.2883 - val_loss: 1.5249 - learning_rate: 0.0010
# Epoch 14/50
# 988/990 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5540 - f1_score: 0.3855 - loss: 1.2496
# Epoch 14: val_accuracy did not improve from 0.47335
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.5539 - f1_score: 0.3854 - loss: 1.2496 - val_accuracy: 0.4718 - val_f1_score: 0.2774 - val_loss: 1.5085 - learning_rate: 0.0010
# Epoch 15/50
# 989/990 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5599 - f1_score: 0.3867 - loss: 1.2152
# Epoch 15: val_accuracy did not improve from 0.47335
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.5599 - f1_score: 0.3867 - loss: 1.2153 - val_accuracy: 0.4650 - val_f1_score: 0.2914 - val_loss: 1.5202 - learning_rate: 0.0010
# Epoch 16/50
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5647 - f1_score: 0.3979 - loss: 1.2037
# Epoch 16: val_accuracy did not improve from 0.47335
# 990/990 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.5647 - f1_score: 0.3979 - loss: 1.2037 - val_accuracy: 0.4673 - val_f1_score: 0.2893 - val_loss: 1.5221 - learning_rate: 0.0010
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4872 - f1_score: 0.2175 - loss: 1.4118
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4309 - f1_score: 0.2573 - loss: 1.6125
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 41
#      37 X_test_scaled = np.expand_dims(X_test_scaled  ,axis =1)
#      39 test_loss, test_acc, test_f1_score = model.evaluate(X_test_scaled, y_test)
# ---> 41 print("Valid Loss: ",val_loss, end=', ')
#      42 print("Valid f1_score: ",val_f1_score, end=', ')
#      43 print("Valid Accuracy: ",val_acc, end=', ')
#
# NameError: name 'val_loss' is not defined

# %%
best_score

# %%
train_text, valid_text = train_test_split(train_csv, test_size=0.3, random_state=42, shuffle=True, stratify=train_csv['감정'])

# %%
train_text_input = Text_Input(train_text)
valid_text_input = Text_Input(valid_text)
test_text_input = Text_Input(test_csv)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
epochs = 5
batch_size = 16
optimizer = AdamW(model.parameters(), lr=5e-6)

# %%
train_loader = DataLoader(train_text_input, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_text_input, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_text_input, batch_size=batch_size, shuffle=True)

# %%
losses = []
accuracies = []

for i in range(epochs):
    total_loss = 0.0
    correct = 0
    total = 0
    batches = 0

    model.train()


for input_ids_batch, attention_masks_batch, y_batch in tqdm(train_loader):
    optimizer.zero_grad()
    y_batch = y_batch.to(device)
    input_ids_batch = input_ids_batch.to(device)
    attention_masks_batch = attention_masks_batch.to(device)
    y_pred = model(input_ids_batch, attention_masks_batch)
    try:
        loss = F.cross_entropy(y_pred, y_batch)
        loss.backward()
        optimizer.step()
    except Exception as e:
        print(e)
        print(input_ids_batch.size(), attention_masks_batch.size(), y_pred.size(), y_batch.size())
        break


    total_loss += loss.item()

    _, predicted = torch.max(y_pred, 1)
    correct += (predicted == y_batch).sum()
    total += len(y_batch)

    batches += 1
    if batches % 100 == 0 and total != 0:
        print("Batch Loss:", total_loss, "Accuracy:", correct / total)
    else:
        accuracies.append(0)

losses.append(total_loss)
accuracies.append(correct / total)
print("Train Loss:", total_loss, "Accuracy:", correct / total)

# %%
losses, accuracies

# %%
# 모델 저장하기
torch.save(model.state_dict(), "./model/1st_koElectraModel.pt")

# %%
model.eval()

test_correct = 0
test_total = 0

for input_ids_batch, attention_masks_batch, y_batch in tqdm(test_loader):
    y_batch = y_batch.to(device)
    y_pred = model(input_ids_batch.to(device), attention_mask=attention_masks_batch.to(device))[0]
    _, predicted = torch.max(y_pred, 1)
    test_correct += (predicted == y_batch).sum()
    test_total += len(y_batch)

print("Accuracy:", test_correct.float() / test_total)

# %% [markdown]
# ### 문제:
#
# - Colab에서 돌려본 텍스트 모델 KoELECTRA 성능이 생각 외로 형편없다....(최종 점검 결과 약 20%)
# - 한 번 더 데이터 확인해 보고 문제 없으면 다른 방법 강구해 보자
# - 그리고 앞으로는 train_test_split이나 KFold로 분리한 train data의 일부는 valid, validation으로 지칭하고 원래 분리해 놓은 세트는 test로 지칭. 용어 혼선이 있었음.

# %% [markdown]
# # 텍스트 전처리
# - 나중에 10차 시도에 잘라 붙일 부분
